# %%
print(input().swapcase())
# 영어 알파벳으로 이루어진 문자열 str이 주어집니다. 각 알파벳을 대무자는 소문자로 소문자는 대문자로 변환해서 출력하는 코드를 작성해보세요
#1 ≤ str의 길이 ≤ 20, str은 알파벳으로 이루어진 문자열입니다.
# Out:
# aBcDeFg
# AbCdEfG

# %%
print(r'!@#$%^&*(\'"<>?:;')
# Out:
# !@#$%^&*(\'"<>?:;

# %%
print(sum(a+b))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b8a971e3b92a> in <cell line: 1>()
# ----> 1 print(sum(a+b))
#
# NameError: name 'a' is not defined

# %%
int a,b
  sum(a,b)
    print(sum)
# Out:
#   File "<ipython-input-5-c11f948ed036>", line 1
#     int a,b
#         ^
# SyntaxError: invalid syntax

# %%
a, b = map(int, input().split())

c = a + b

print(f"{a} + {b} = {c}")
# Out:
# 4 5
# 4 + 5 = 9
