# %%
menu = input()
# Out:
# 햄버거

# %%
for pass = 1 to n-1
for i = 1 to n-pass
if(A[i-1]> A[i])
a[i-1]<->A[i]
return A
# Out:
#   File "<ipython-input-2-e27f9b24caf7>", line 1
#     for pass = 1 to n-1
#            ^
# SyntaxError: invalid syntax
